# %%
from sklearn.datasets import fetch_20newsgroups

data = fetch_20newsgroups(subset='train')
X = data.data
y = data.target

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(stop_words='english')
X_transformed = vectorizer.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_transformed, y, test_size=0.2)

# %%
from sklearn.naive_bayes import MultinomialNB

nb = MultinomialNB()
nb.fit(X_train, y_train)
acc_nb = nb.score(X_test, y_test)

print("Naive Bayes Accuracy:", acc_nb)
# Out:
# Naive Bayes Accuracy: 0.8661069376933275

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_3 = KNeighborsClassifier(n_neighbors=3)
knn_3.fit(X_train, y_train)
acc = knn_3.score(X_test, y_test)

print("KNN (k=3) Accuracy:", acc)
# Out:
# KNN (k=3) Accuracy: 0.7799381352187362

# %%
knn_5 = KNeighborsClassifier(n_neighbors=5)
knn_5.fit(X_train, y_train)
acc_knn5 = knn_5.score(X_test, y_test)

print("KNN (k=5) Accuracy:", acc_knn5)
# Out:
# KNN (k=5) Accuracy: 0.7865665046398586

# %%
knn_7 = KNeighborsClassifier(n_neighbors=7)
knn_7.fit(X_train, y_train)
y_pred_7 = knn_7.predict(X_test)

print("KNN (k=7) Accuracy:", accuracy_score(y_test, y_pred_7))
# Out:
# KNN (k=7) Accuracy: 0.7755192222713213

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier

lr_l1 = OneVsRestClassifier(LogisticRegression(l1_ratio=1, solver= 'liblinear', max_iter=100))
lr_l1.fit(X_train, y_train)
l1_acc = lr_l1.score(X_test, y_test)

print("Logistic Regression (L1) Accuracy:", l1_acc)
# Out:
# Logistic Regression (L1) Accuracy: 0.8015908086610694

# %%
lr_model_l2 = OneVsRestClassifier(LogisticRegression(l1_ratio=0, solver= 'liblinear', max_iter=100))
lr_model_l2.fit(X_train, y_train)
lr2_acc = lr_model_l2.score(X_test, y_test)
print("Logistic Regression (L2) Accuracy:", lr2_acc)
# Out:
# Logistic Regression (L2) Accuracy: 0.8859920459566947
